# %% [markdown]
# # Yeast Polarization Example

# %% [markdown]
# This is a model of spontations polarization in Yeast.  It is based on the model published in Altschuler 2008.  The spatial domain for the model is a 3D sphere with the surface of the sphere reperesnting the membrane of the yeast cell and the volume of the sphere reperesenting the cytoplasm.  Cytoplasmic Cdc42 (species "A") can spontantously associate with the membrate, becoming membrane bound (Species "B").  Membrance bound Cdc42 can diffuse only on the membrane, but can spontaneously disaccociate, becoming "A" again.  "B" on the membrane act to recruit more "A" to the membrane.

# %%
import os
from pyurdme import pyurdme
import dolfin
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
import numpy

# %%
class membrane(dolfin.SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary
        #return numpy.sqrt(x[0]*x[0]+x[1]*x[1]) > (5-.2)
        #return numpy.sqrt(x[0]*x[0]+x[1]*x[1]+x[2]*x[2]) > (5-.2)

# %%
class polarization(pyurdme.URDMEModel):
    def __init__(self, model_name="polarization"):
        pyurdme.URDMEModel.__init__(self, model_name)

        # System constants
        D_membrane = 0.0053    #diffusion on the membrane from Altschuler
        D_bulk = 10          #not sure of bulk diffusion const
        k_on = pyurdme.Parameter(name="k_on", expression=0.001/60)     #clustering for small values of this?
        k_off = pyurdme.Parameter(name="k_off", expression=9000.0/60)   #from Altschuler
        k_fb = pyurdme.Parameter(name="k_fb", expression=10000.0/60)    #from Altschuler
        self.add_parameter([k_on, k_off, k_fb])

        # Define Species
        A = pyurdme.Species(name="A", diffusion_constant=D_bulk)
        B = pyurdme.Species(name="B", diffusion_constant=D_membrane)
        self.add_species([A, B])

        #Define Geometry
        sphere = dolfin.Sphere(dolfin.Point(0.0, 0.0, 0.0), 5.0)
        self.mesh = pyurdme.URDMEMesh(mesh=dolfin.Mesh(sphere, 25))

        # Define Subdomains
        subdomains = dolfin.MeshFunction("size_t", self.mesh, self.mesh.topology().dim()-1)
        subdomains.set_all(1)
        # Mark the membrane as subdomain 2
        membrane().mark(subdomains,2)
        self.add_subdomain(subdomains)

        # Define Reactions
        R1 = pyurdme.Reaction(name="R1", reactants={A:1}, products={B:1}, 
           massaction=True, rate=k_on, restrict_to=2)
        R2 = pyurdme.Reaction(name="R2", reactants={B:1}, products={A:1}, 
            massaction=True, rate=k_off, restrict_to=2)
        R3 = pyurdme.Reaction(name="R3", reactants={A:1, B:1}, products={B:2}, 
            massaction=True, rate=k_fb)
        self.add_reaction([R1, R2, R3])
        
        # Define simulation timespan
        self.timespan(range(1000))
        #Define initial populations
        self.set_initial_condition_scatter({A:10000},[1])

# %%
model = polarization()

# %%
# %time result = model.run()
# Out:
# CPU times: user 1min 16s, sys: 740 ms, total: 1min 17s
# Wall time: 8min 56s

# %%
A_vals = result.get_species('A', timepoints=-1, concentration=True)
B_vals = result.get_species('B', timepoints=-1, concentration=True)
x_vals = model.mesh.coordinates()[:, 0]
y_vals = model.mesh.coordinates()[:, 1]
z_vals = model.mesh.coordinates()[:, 2]
plt.subplot(2,3,1)
plt.plot(x_vals,A_vals,'.')
plt.title('A x')
plt.subplot(2,3,2)
plt.plot(y_vals,A_vals,'.')
plt.title('A y')
plt.subplot(2,3,3)
plt.plot(z_vals,A_vals,'.')
plt.title('A z')
plt.subplot(2,3,4)
plt.plot(x_vals,B_vals,'.')
plt.title('B x')
plt.subplot(2,3,5)
plt.plot(y_vals,B_vals,'.')
plt.title('B y')
plt.subplot(2,3,6)
plt.plot(z_vals,B_vals,'.')
plt.title('B z')
print "sum(A)={0}  sum(B)={1}".format(numpy.sum(A_vals), numpy.sum(B_vals))
# Out:
# sum(A)=4.67884343295e-23  sum(B)=2.49434927873e-19

# %%
B_vs_time=[]
for n,t in enumerate(model.tspan):
    B_vals = result.get_species('B', timepoints=n, concentration=True)
    B_vs_time.append(numpy.sum(B_vals))
    
plt.plot(B_vs_time)

# %%
data = model.get_solver_datastructure()
sd = data['sd']
print "sd1={0}  sd2={0}".format(numpy.sum(sd==1),numpy.sum(sd==2))
# Out:
# sd1=5314  sd2=5314

# %%
result.display("A",500)
# Out:
# <div id="75c00003-7129-4f0f-a0f1-a846968768b5" class="cell"></div><script>
#   renderPyURDMEMesh({"faces": [128, 1011, 4302, 6101, 1011, 4302, 6101, 128, 289, 4302, 6101, 289, 4302, 6101, 128, 289, 1011, 6101, 289, 1011, 6101, 128, 289, 1011, 4302, 289, 1011, 4302, 128, 599, 1100, 4013, 599, 1100, 4013, 128, 160, 1100, 4013, 160, 1100, 4013, 128, 160, 599, 4013, 160, 599, 4013, 128, 160, 599, 1100, 160, 599, 1100, 128, 825, 2488, 4558, 825, 2488, 4558, 128, 279, 2488, 4558, 279, 2488, 4558, 128, 279, 825, 4558, 279, 825, 4558, 128, 279, 825, 2488, 279, 825, 2488, 128, 2906, 3115, 5166, 2906, 3115, 5166, 128, 1675, 3115, 5166, 1675, 3115, 5166, 128, 1675, 2906, 5166, 1675, 2906, 5166, 128, 1675, 2906, 3115, 1675, 2906, 3115, 128, 2398, 5195, 5959, 2398, 5195, 5959, 128, 1475, 5195, 5959, 1475, 5195, 5959, 128, 1475, 2398, 5959, 1475, 2398, 5959, 128, 1475, 2398, 5195, 1475, 2398, 5195, 128, 3561, 4441, 5435, 3561, 4441, 5435, 128, 1966, 4441, 5435, 1966, 4441, 5435, 128, 1966, 3561, 5435, 1966, 3561, 5435, 128, 1966, 3561, 4441, 1966, 3561, 4441, 128, 2212, 4535, 5281, 2212, 4535, 5281, 128, 1497, 4535, 5281, 1497, 4535, 5281, 128, 1497, 2212, 5281, 1497, 2212, 5281, 128, 1497, 2212, 4535, 1497, 2212, 4535, 128, 2913, 3747, 4210, 2913, 3747, 4210, 128, 1739, 3747, 4210, 1739, 3747, 4210, 128, 1739, 2913, 4210, 1739, 2913, 4210, 128, 1739,
 379, 4218, 6085, 379, 4218, 6085, 128, 379, 666, 6085, 379, 666, 6085, 128, 379, 666, 4218, 379, 666, 4218, 128, 519, 580, 2987, 519, 580, 2987, 128, 190, 580, 2987, 190, 580, 2987, 128, 190, 519, 2987, 190, 519, 2987, 128, 190, 519, 580, 190, 519, 580, 128, 2644, 3140, 3465, 2644, 3140, 3465, 128, 1568, 3140, 3465, 1568, 3140, 3465, 128, 1568, 2644, 3465, 1568, 2644, 3465, 128, 1568, 2644, 3140, 1568, 2644, 3140, 128, 2727, 3292, 6478, 2727, 3292, 6478, 128, 2316, 3292, 6478, 2316, 3292, 6478, 128, 2316, 2727, 6478, 2316, 2727, 6478,  ...

# %%
result.display("B",900)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ebf24ba8b76a> in <module>()
# ----> 1 result.display("B",900)
#
# /home/ubuntu/pyurdme/pyurdme/pyurdme.pyc in display(self, species, time_index)
#    1630     def display(self,species,time_index):
#    1631
# -> 1632         jstr = self.export_to_three_js(species,time_index)
#    1633         hstr = None
#    1634         with open(os.path.dirname(os.path.abspath(__file__))+"/data/three.js_templates/solution.html",'r') as fd:
#
# /home/ubuntu/pyurdme/pyurdme/pyurdme.pyc in export_to_three_js(self, species, time_index)
#    1578
#    1579         colors = self._compute_solution_colors(species,time_index)
# -> 1580         return self.model.mesh.export_to_three_js(colors=colors)
#    1581
#    1582     def _copynumber_to_concentration(self,copy_number_data):
#
# /home/ubuntu/pyurdme/pyurdme/pyurdme.pyc in export_to_three_js(self, colors)
#    1102                 f.append(int(ind))
#    1103             faces += ([128]+f+f)
# -> 1104             document["faces"] = list(faces)
#    1105
#    1106         #Test that we can index into vertices
#
# KeyboardInterrupt:

# %%
#model.mesh

# %%
# This is the sum of all populations for each time point
x_vals = model.mesh.coordinates()[:, 0]
y_vals = model.mesh.coordinates()[:, 1]
z_vals = model.mesh.coordinates()[:, 2]
l = x_vals.shape[0]
print 'Number of x values in the mesh: ' + repr(l)
A_vals = numpy.sum(result['U'][0:2 * l - 1:2, :], axis=0)
B_vals = numpy.sum(result['U'][1:2 * l:2, :], axis=0)
print 'Number of time points : ' + repr(A_vals.shape[0])
print 'Number of time points : ' + repr(B_vals.shape[0])

plt.subplot(1, 2, 1)
plt.plot(A_vals, '.r')
plt.subplot(1, 2, 2)
plt.plot(B_vals, '.b')
plt.show()

# %%
# Plot of the time-average spatial concentration. i.e. each point is a average of one voxel over all times
A_vals_tavg = numpy.sum(result.get_species('A', concentration=True), axis=0)
B_vals_tavg = numpy.sum(result.get_species('B', concentration=True), axis=0)
#plt.plot(x_vals,A_vals,'.r',x_vals,B_vals,'.b')
plt.clf()
plt.subplot(1, 2, 1)
plt.plot(x_vals,A_vals_tavg,'.r')
plt.legend('A')
plt.subplot(1, 2, 2)
plt.plot(x_vals,B_vals_tavg,'.b')
plt.legend('B')
plt.show()
