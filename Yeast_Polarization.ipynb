# %% [markdown]
# # Yeast Polarization Example

# %% [markdown]
# This is a model of spontations polarization in Yeast.  It is based on the model published in Altschuler 2008.  The spatial domain for the model is a 3D sphere with the surface of the sphere reperesnting the membrane of the yeast cell and the volume of the sphere reperesenting the cytoplasm.  Cytoplasmic Cdc42 (species "A") can spontantously associate with the membrate, becoming membrane bound (Species "B").  Membrance bound Cdc42 can diffuse only on the membrane, but can spontaneously disaccociate, becoming "A" again.  "B" on the membrane act to recruit more "A" to the membrane.

# %%
import os
from pyurdme import pyurdme
import dolfin
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
import numpy

# %%
class membrane(dolfin.SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary
        #return numpy.sqrt(x[0]*x[0]+x[1]*x[1]) > (5-.2)
        #return numpy.sqrt(x[0]*x[0]+x[1]*x[1]+x[2]*x[2]) > (5-.2)

# %%
class polarization(pyurdme.URDMEModel):
    def __init__(self, model_name="polarization"):
        pyurdme.URDMEModel.__init__(self, model_name)

        # System constants
        D_membrane = 0.02    #diffusion on the membrane from Altschuler
        D_bulk = 2          #not sure of bulk diffusion const
        k_on = pyurdme.Parameter(name="k_on", expression=0.1/60)     #clustering for small values of this?
        k_off = pyurdme.Parameter(name="k_off", expression=9.0/60)   #from Altschuler
        k_fb = pyurdme.Parameter(name="k_fb", expression=10.0/60)    #from Altschuler
        self.add_parameter([k_on, k_off, k_fb])

        # Define Species
        A = pyurdme.Species(name="A", diffusion_constant=D_bulk)
        B = pyurdme.Species(name="B", diffusion_constant=D_membrane)
        self.add_species([A, B])

        #Define Geometry
        sphere = dolfin.Sphere(dolfin.Point(0.0, 0.0, 0.0), 5.0)
        self.mesh = pyurdme.URDMEMesh(mesh=dolfin.Mesh(sphere, 25))

        # Define Subdomains
        subdomains = dolfin.MeshFunction("size_t", self.mesh, self.mesh.topology().dim()-1)
        subdomains.set_all(1)
        # Mark the membrane as subdomain 2
        membrane().mark(subdomains,2)
        self.add_subdomain(subdomains)

        # Define Reactions
        R1 = pyurdme.Reaction(name="R1", reactants={A:1}, products={B:1}, 
           massaction=True, rate=k_on, restrict_to=2)
        R2 = pyurdme.Reaction(name="R2", reactants={B:1}, products={A:1}, 
            massaction=True, rate=k_off, restrict_to=2)
        R3 = pyurdme.Reaction(name="R3", reactants={A:1, B:1}, products={B:2}, 
            massaction=True, rate=k_fb)
        self.add_reaction([R1, R2, R3])
        
        # Define simulation timespan
        self.timespan(range(1000))
        #Define initial populations
        self.set_initial_condition_scatter({A:600},[1])

# %%
model = polarization()

# %%
# %time result = model.run()
# Out:
# CPU times: user 1min 18s, sys: 808 ms, total: 1min 19s
# Wall time: 1min 30s

# %%
A_vals = result.get_species('A', timepoints=-1, concentration=True)
B_vals = result.get_species('B', timepoints=-1, concentration=True)
x_vals = model.mesh.coordinates()[:, 0]
y_vals = model.mesh.coordinates()[:, 1]
z_vals = model.mesh.coordinates()[:, 2]
plt.subplot(2,3,1)
plt.plot(x_vals,A_vals,'.')
plt.title('A x')
plt.subplot(2,3,2)
plt.plot(y_vals,A_vals,'.')
plt.title('A y')
plt.subplot(2,3,3)
plt.plot(z_vals,A_vals,'.')
plt.title('A z')
plt.subplot(2,3,4)
plt.plot(x_vals,B_vals,'.')
plt.title('B x')
plt.subplot(2,3,5)
plt.plot(y_vals,B_vals,'.')
plt.title('B y')
plt.subplot(2,3,6)
plt.plot(z_vals,B_vals,'.')
plt.title('B z')
print "sum(A)={0}  sum(B)={1}".format(numpy.sum(A_vals), numpy.sum(B_vals))
# Out:
# sum(A)=5.85186183389e-22  sum(B)=1.4067994356e-20

# %%
data = model.get_solver_datastructure()
sd = data['sd']
print "sd1={0}  sd2={0}".format(numpy.sum(sd==1),numpy.sum(sd==2))
# Out:
# sd1=5323  sd2=5323

# %%
result.display("A",500)
# Out:
# <div id="b543eb19-c26b-47dd-97dc-d39db6a1cfae" class="cell"></div><script>
#   renderPyURDMEMesh({"faces": [128, 3390, 4016, 5594, 3390, 4016, 5594, 128, 1643, 4016, 5594, 1643, 4016, 5594, 128, 1643, 3390, 5594, 1643, 3390, 5594, 128, 1643, 3390, 4016, 1643, 3390, 4016, 128, 827, 901, 6027, 827, 901, 6027, 128, 247, 901, 6027, 247, 901, 6027, 128, 247, 827, 6027, 247, 827, 6027, 128, 247, 827, 901, 247, 827, 901, 128, 1984, 3542, 3782, 1984, 3542, 3782, 128, 1725, 3542, 3782, 1725, 3542, 3782, 128, 1725, 1984, 3782, 1725, 1984, 3782, 128, 1725, 1984, 3542, 1725, 1984, 3542, 128, 2445, 3367, 4704, 2445, 3367, 4704, 128, 1813, 3367, 4704, 1813, 3367, 4704, 128, 1813, 2445, 4704, 1813, 2445, 4704, 128, 1813, 2445, 3367, 1813, 2445, 3367, 128, 2490, 5024, 5862, 2490, 5024, 5862, 128, 1728, 5024, 5862, 1728, 5024, 5862, 128, 1728, 2490, 5862, 1728, 2490, 5862, 128, 1728, 2490, 5024, 1728, 2490, 5024, 128, 2866, 3580, 4436, 2866, 3580, 4436, 128, 1691, 3580, 4436, 1691, 3580, 4436, 128, 1691, 2866, 4436, 1691, 2866, 4436, 128, 1691, 2866, 3580, 1691, 2866, 3580, 128, 879, 1156, 3179, 879, 1156, 3179, 128, 31, 1156, 3179, 31, 1156, 3179, 128, 31, 879, 3179, 31, 879, 3179, 128, 31, 879, 1156, 31, 879, 1156, 128, 2707, 3848, 4961, 2707, 3848, 4961, 128, 1498, 3848, 4961, 1498, 3848, 4961, 128, 1498, 2707, 4961, 1498, 2707, 4961, 128, 1498, 2707, 3848, 1498, 2707, 3848, 128, 3291, 4409, 6459, 3291, 4409, 6459, 128, 1353, 4409, 6459, 1353, 4409, 6459, 128, 1353, 3291, 6459, 1353, 3291, 6459, 128, 1353, 3291, 4409, 1353, 3291, 4409, 128, 3392, 5695, 5696, 3392, 5695, 5696, 128, 2322, 5695, 5696, 2322, 5695, 5696, 128, 2322, 3392, 5696, 2322, 3392, 5696, 128, 2322, 3392, 5695, 2322, 3392, 5695, 128, 3529, 3899, 6272, 3529, 3899, 6272, 128, 1922, 3899, 6272, 1922, 3899, 6272, 128, 1922, 3529, 6272, 1922, 3529, 6272, 128, 1922, 3529, 3899, 1922, 3529, 3899, 128, 3244, 4220, 4965, 3244, 4220, 4965, 128, 1370, 4220, 4965, 1370, 4220, 4965, 128
99, 107, 120, 128, 99, 107, 114, 99, 107, 114, 128, 103, 119, 122, 103, 119, 122, 128, 5, 119, 122, 5, 119, 122, 128, 5, 103, 122, 5, 103, 122, 128, 5, 103, 119, 5, 103, 119, 128, 61, 95, 120, 61, 95, 120, 128, 36, 95, 120, 36, 95, 120, 128, 36, 61, 95, 36, 61, 95, 128, 42, 63, 116, 42, 63, 116, 128, 22, 63, 116, 22, 63, 116, 128, 22, 42, 116, 22, 42, 116, 128, 22, 42, 63, 22, 42, 63, 128, 4, 77, 105, 4, 77, 105, 128, 4, 67, 105, 4, 67, 105, 128, 4, 67, 77, 4, 67, 77, 128, 107, 113, 123, 107, 113, 123, 128, 104, 107, 123, 104, 107, 123, 128, 104, 107, 113, 104, 107, 113, 128, 52, 70, 122, 52, 70, 122, 128, 28, 52, 122, 28, 52, 122, 128, 28, 52, 70, 28, 52, 70, 128, 20, 95, 120, 20, 95, 120, 128, 20, 61, 120, 20, 61, 120, 128, 20, 61, 95, 20, 61, 95, 128, 91, 99, 120, 91, 99, 120, 128, 18, 99, 120, 18, 99, 120, 128, 18, 91, 120, 18, 91, 120, 128, 18, 91, 99, 18, 91, 99, 128, 107, 116, 123, 107, 116, 123, 128, 104, 107, 116, 104, 107, 116, 128, 113, 120, 123, 113, 120, 123, 128, 88, 120, 123, 88, 120, 123, 128, 88, 113, 123, 88, 113, 123, 128, 88, 113, 120, 88, 113, 120, 128, 84, 109, 121, 84, 109, 121, 128, 39, 109, 121, 39, 109, 121, 128, 39, 84, 121, 39, 84, 121, 128, 39, 84, 109, 39, 84, 109, 128, 62, 64, 111, 62, 64, 111, 128, 8, 64, 111, 8, 64, 111, 128, 8, 62, 64, 8, 62, 64, 128, 81, 113, 123, 81, 113, 123, 128, 81, 108, 113, 81, 108, 113, 128, 61, 120, 121, 61, 120, 121, 128, 20, 120, 121, 20, 120, 121, 128, 20,  ...

# %%
# This is the sum of all populations for each time point
x_vals = model.mesh.coordinates()[:, 0]
y_vals = model.mesh.coordinates()[:, 1]
z_vals = model.mesh.coordinates()[:, 2]
l = x_vals.shape[0]
print 'Number of x values in the mesh: ' + repr(l)
A_vals = numpy.sum(result['U'][0:2 * l - 1:2, :], axis=0)
B_vals = numpy.sum(result['U'][1:2 * l:2, :], axis=0)
print 'Number of time points : ' + repr(A_vals.shape[0])
print 'Number of time points : ' + repr(B_vals.shape[0])

plt.subplot(1, 2, 1)
plt.plot(A_vals, '.r')
plt.subplot(1, 2, 2)
plt.plot(B_vals, '.b')
plt.show()
# Out:
# Number of x values in the mesh: 119
# Number of time points : 238
# Number of time points : 238

# %%
# Plot of the time-average spatial concentration. i.e. each point is a average of one voxel over all times
A_vals_tavg = numpy.sum(result.get_species('A', concentration=True), axis=0)
B_vals_tavg = numpy.sum(result.get_species('B', concentration=True), axis=0)
#plt.plot(x_vals,A_vals,'.r',x_vals,B_vals,'.b')
plt.clf()
plt.subplot(1, 2, 1)
plt.plot(x_vals,A_vals_tavg,'.r')
plt.legend('A')
plt.subplot(1, 2, 2)
plt.plot(x_vals,B_vals_tavg,'.b')
plt.legend('B')
plt.show()
