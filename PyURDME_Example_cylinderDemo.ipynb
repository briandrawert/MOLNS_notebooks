# %% [markdown]
# # Cylinder Annihilation Demo

# %% [markdown]
# In this demo, we use the constructive solid geometry method to create a spatial domain in the shape of a cylinder. The cylinder has it's long dimension (x-axis) from -5 to 5, the circular dimension has diamater of 1.

# %%
from matplotlib import pyplot as plt
from IPython.display import clear_output
import pyurdme
import dolfin

# %%
# These classes are used to define the subdomains
class Edge1(dolfin.SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and dolfin.near(x[0], 5.0)
class Edge2(dolfin.SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and dolfin.near(x[0], -5.0)

# %%
class cylinderDemo3D(pyurdme.URDMEModel):
    def __init__(self, model_name="cylinder_demo3d"):
        pyurdme.URDMEModel.__init__(self, model_name)
        # Define Species
        A = pyurdme.Species(name="A", diffusion_constant=1.0)
        B = pyurdme.Species(name="B", diffusion_constant=1.0)
        self.add_species([A, B])
        # Define Geometry
        cylinder = dolfin.Cylinder(dolfin.Point(5, 0, 0), dolfin.Point(-5, 0, 0), 1.0)
        self.mesh = pyurdme.URDMEMesh(mesh=dolfin.Mesh(cylinder, 50))
        # Define Subdomains
        self.add_subdomain(Edge1(), 2)
        self.add_subdomain(Edge2(), 3)
        # This section is a fix to ensure the creation rates are equal.  Since
        # The creation reactions are zero-th order, They are proportional to volume.
        # Due to the discritization the sum volume of the voxels in subdomain 1 may
        # not be the same as the sum volume of the voxels in subdomain 2.  We adjust 
        # the parameters so that the net creation rate the same for both. 
        data = self.get_solver_datastructure()
        vol = data['vol']
        sd = data['sd']
        left = numpy.sum(vol[sd == 2])
        right = numpy.sum(vol[sd == 3])
        print "Vol: Left(A)={0} right(B)={1}".format(left, right)
        # left (sd=2) right (sd=3)
        k_creat = 100
        k_creat1_val = k_creat/left
        k_creat2_val = k_creat/right
        print "Net create rate: A={0} B={1}".format(k_creat1_val, k_creat2_val)
        
        # Define Parameters
        k_react = pyurdme.Parameter(name="k_react", expression=1.0)
        k_create1 = pyurdme.Parameter(name="k_create1", expression=k_creat1_val)
        k_create2 = pyurdme.Parameter(name="k_create1", expression=k_creat2_val)
        self.add_parameter([k_react, k_create1, k_create2])
        # Define Reactions
        R1 = pyurdme.Reaction(name="R1", reactants=None, products={A:1}, rate=k_create1, restrict_to=2)
        R2 = pyurdme.Reaction(name="R2", reactants=None, products={B:1}, rate=k_create2, restrict_to=3)
        R3 = pyurdme.Reaction(name="R3", reactants={A:1, B:1}, products=None, rate=k_react)
        self.add_reaction([R1, R2, R3])
        # Define simulation timespan
        self.timespan(range(200))

# %%
model = cylinderDemo3D()
# Out:
# Vol: Left(A)=0.257997282994 right(B)=0.159705662237
# Net create rate: A=387.600981062 B=626.151875891

# %% [markdown]
# ## Simulate the System

# %%
# %time result = model.run()
# Out:
# CPU times: user 4.64 s, sys: 68.2 ms, total: 4.71 s
plt.hist(x_vals, bins=num_bins, weights=B_vals, facecolor='red', alpha=0.5)
plt.hist(x_vals, bins=num_bins, weights=A_vals, facecolor='blue', alpha=0.5)
plt.legend(['B','A'])
plt.xlabel('x-coordinate')
plt.ylabel('Population')
plt.title('Population binned by x-coordinate')

# %%
x_vals = model.mesh.coordinates()[:,0]
A_vals = result.get_species('A', concentration=True)
B_vals = result.get_species('B', concentration=True)
for tndx, tval in enumerate(model.tspan):
    plt.plot(x_vals, A_vals[tndx,:],'.b', x_vals, B_vals[tndx,:],'.r')
    plt.legend(['A','B'])
    plt.title('t={0}'.format(tval))
    clear_output()
    plt.show()

# %%
result.display('A',199)
# Out:
# <div id="12c08786-a732-4540-8278-c0d0ed19979d" class="cell"></div><script>
#   renderPyURDMEMesh({"faces": [128, 395, 479, 620, 395, 479, 620, 128, 51, 479, 620, 51, 479, 620, 128, 51, 395, 620, 51, 395, 620, 128, 51, 395, 479, 51, 395, 479, 128, 274, 360, 592, 274, 360, 592, 128, 49, 360, 592, 49, 360, 592, 128, 49, 274, 592, 49, 274, 592, 128, 49, 274, 360, 49, 274, 360, 128, 506, 775, 951, 506, 775, 951, 128, 355, 775, 951, 355, 775, 951, 128, 355, 506, 951, 355, 506, 951, 128, 355, 506, 775, 355, 506, 775, 128, 419, 840, 1036, 419, 840, 1036, 128, 59, 840, 1036, 59, 840, 1036, 128, 59, 419, 1036, 59, 419, 1036, 128, 59, 419, 840, 59, 419, 840, 128, 357, 431, 945, 357, 431, 945, 128, 197, 431, 945, 197, 431, 945, 128, 197, 357, 945, 197, 357, 945, 128, 197, 357, 431, 197, 357, 431, 128, 620, 881, 918, 620, 881, 918, 128, 546, 881, 918, 546, 881, 918, 128, 546, 620, 918, 546, 620, 918, 128, 546, 620, 881, 546, 620, 881, 128, 620, 860, 918, 620, 860, 918, 128, 575, 860, 918, 575, 860, 918, 128, 575, 620, 918, 575, 620, 918, 128, 575, 620, 860, 575, 620, 860, 128, 663, 918, 946, 663, 918, 946, 128, 575, 918, 946, 575, 918, 946, 128, 575, 663, 946, 575, 663, 946, 128, 575, 663, 918, 575, 663, 918, 128, 126, 429, 624, 126, 429, 624, 128, 80, 429, 624, 80, 429, 624, 128, 80, 126, 624, 80, 126, 624, 128, 80, 126, 429, 80, 126, 429, 128, 700, 894, 982, 700, 894, 982, 128, 544, 894, 982, 544, 894, 982, 128, 544, 700, 982, 544, 700, 982, 128, 544, 700, 894, 544, 700, 894, 128, 808, 945, 979, 808, 945, 979, 128, 604, 945, 979, 604, 945, 979, 128, 604, 808, 979, 604, 808, 979, 128, 604, 808, 945, 604, 808, 945, 128, 707, 739, 905, 707, 739, 905, 128, 542, 739, 905, 542, 739, 905, 128, 542, 707, 905, 542, 707, 905, 128, 542, 707, 739, 542,